# %% [markdown]
# # SMS Spam Detection 📱
# This notebook demonstrates an end-to-end machine learning pipeline for classifying SMS messages as spam or ham.
#
# ## Sections
# 1. Import Libraries
# 2. Load Dataset
# 3. Data Cleaning & Preprocessing
# 4. Exploratory Data Analysis (EDA)
# 5. Feature Engineering (TF-IDF)
# 6. Model Training (Naive Bayes, Logistic Regression)
# 7. Model Evaluation
# 8. Results & Conclusion

# %% [markdown]
# # SMS Spam Detection

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('spam.csv',encoding="latin1")

# %%
df.sample(5)
# Out:
#        v1                                                 v2 Unnamed: 2  \
# 2902  ham                        Tell me pa. How is pain de.        NaN
# 2836  ham                            1's reach home call me.        NaN
# 1442  ham             Its ok., i just askd did u knw tht no?        NaN
# 3471  ham  I think IÛ÷m waiting for the same bus! Inform...        NaN
# 2141  ham             Alright took the morphine. Back in yo.        NaN
#
#      Unnamed: 3 Unnamed: 4
# 2902        NaN        NaN
# 2836        NaN        NaN
# 1442        NaN        NaN
# 3471        NaN        NaN
# 2141        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %% [markdown]
# # 1. Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df.drop(columns=['Unnamed: 2',	'Unnamed: 3',	'Unnamed: 4'],inplace=True)

# %%
df.sample(5)
# Out:
#         v1                                                 v2
# 2413   ham  Lol please do. Actually send a pic of yourself...
# 2296  spam  <Forwarded from 21870000>Hi - this is your Mai...
# 3206   ham          This phone has the weirdest auto correct.
# 2166   ham            Thank you. And by the way, I just lost.
# 3044   ham  Hello, yeah i've just got out of the bath and ...

# %%
df.rename(columns={'v1':'target','v2':'text'},inplace=True)

# %%
df.sample(5)
# Out:
#      target                                               text
# 5035   spam  You won't believe it but it's true. It's Incre...
# 2292    ham                         :-( that's not v romantic!
# 17      ham  Eh u remember how 2 spell his name... Yes i di...
# 4257    ham                      I am late. I will be there at
# 4504   spam  Mobile Club: Choose any of the top quality ite...

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
encoder.fit_transform(df['target'])
# Out:
# array([0, 0, 1, ..., 0, 0, 0], shape=(5572,))

# %%
df['target']=encoder.fit_transform(df['target'])

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(403)

# %%
df.drop_duplicates(keep='first')
# Out:
#       target                                               text
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
# [5169 rows x 2 columns]

# %%
df=df.drop_duplicates(keep='first')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# # 2. Exploratory Data Analyis (EDA)

# %%
df['target'].value_counts()
# Out:
# target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['target'].value_counts(),labels=['ham','spam'],autopct='%0.2f')
plt.show()

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from nltk) (8.3.0)
# Requirement already satisfied: joblib in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from nltk) (2025.9.18)
# Requirement already satisfied: tqdm in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df['num_character']=df['text'].apply(len)

# %%
df.head()
# Out:
#    target                                               text  num_character
# 0       0  Go until jurong point, crazy.. Available only ...            111
# 1       0                      Ok lar... Joking wif u oni...             29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...            155
# 3       0  U dun say so early hor... U c already then say...             49
# 4       0  Nah I don't think he goes to usf, he lives aro...             61

# %%
df['text'].apply(lambda x:nltk.word_tokenize(x))
# Out:
# 0       [Go, until, jurong, point, ,, crazy, .., Avail...
# 1                [Ok, lar, ..., Joking, wif, u, oni, ...]
# 2       [Free, entry, in, 2, a, wkly, comp, to, win, F...
# 3       [U, dun, say, so, early, hor, ..., U, c, alrea...
# 4       [Nah, I, do, n't, think, he, goes, to, usf, ,,...
#                               ...
# 5567    [This, is, the, 2nd, time, we, have, tried, 2,...
# 5568     [Will, Ì_, b, going, to, esplanade, fr, home, ?]
# 5569    [Pity, ,, *, was, in, mood, for, that, ., So, ...
# 5570    [The, guy, did, some, bitching, but, I, acted,...
# 5571                  [Rofl, ., Its, true, to, its, name]
# Name: text, Length: 5169, dtype: object

# %%
df['text'].apply(lambda x:len(nltk.word_tokenize(x)))
# Out:
# 0       24
# 1        8
# 2       37
# 3       13
# 4       15
#         ..
# 5567    35
# 5568     9
# 5569    15
# 5570    27
# 5571     7
# Name: text, Length: 5169, dtype: int64

# %%
df['num_words']=df['text'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_character  \
# 0       0  Go until jurong point, crazy.. Available only ...            111
# 1       0                      Ok lar... Joking wif u oni...             29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...            155
# 3       0  U dun say so early hor... U c already then say...             49
# 4       0  Nah I don't think he goes to usf, he lives aro...             61
#
#    num_words
# 0         24
# 1          8
# 2         37
# 3         13
# 4         15

# %%
df['text'].apply(lambda x:nltk.sent_tokenize(x))
# Out:
# 0       [Go until jurong point, crazy.., Available onl...
# 1                        [Ok lar..., Joking wif u oni...]
# 2       [Free entry in 2 a wkly comp to win FA Cup fin...
# 3       [U dun say so early hor... U c already then sa...
# 4       [Nah I don't think he goes to usf, he lives ar...
#                               ...
# 5567    [This is the 2nd time we have tried 2 contact ...
# 5568              [Will Ì_ b going to esplanade fr home?]
# 5569    [Pity, * was in mood for that., So...any other...
# 5570    [The guy did some bitching but I acted like i'...
# 5571                        [Rofl., Its true to its name]
# Name: text, Length: 5169, dtype: object

# %%
df['num_sentences']=df['text'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_character  \
# 0       0  Go until jurong point, crazy.. Available only ...            111
# 1       0                      Ok lar... Joking wif u oni...             29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...            155
# 3       0  U dun say so early hor... U c already then say...             49
# 4       0  Nah I don't think he goes to usf, he lives aro...             61
#
#    num_words  num_sentences
# 0         24              2
# 1          8              2
# 2         37              2
# 3         13              1
# 4         15              1

# %%
df[['num_character','num_words','num_sentences']].describe()
# Out:
#        num_character    num_words  num_sentences
# count    5169.000000  5169.000000    5169.000000
# mean       78.977945    18.455794       1.965564
# std        58.236293    13.324758       1.448541
# min         2.000000     1.000000       1.000000
# 25%        36.000000     9.000000       1.000000
# 50%        60.000000    15.000000       1.000000
# 75%       117.000000    26.000000       2.000000
# max       910.000000   220.000000      38.000000

# %%
df[df['target']==0][['num_character','num_words','num_sentences']].describe()
# Out:
#        num_character    num_words  num_sentences
# count    4516.000000  4516.000000    4516.000000
# mean       70.459256    17.123782       1.820195
# std        56.358207    13.493970       1.383657
# min         2.000000     1.000000       1.000000
# 25%        34.000000     8.000000       1.000000
# 50%        52.000000    13.000000       1.000000
# 75%        90.000000    22.000000       2.000000
# max       910.000000   220.000000      38.000000

# %%
df[df['target']==1][['num_character','num_words','num_sentences']].describe()
# Out:
#        num_character   num_words  num_sentences
# count     653.000000  653.000000     653.000000
# mean      137.891271   27.667688       2.970904
# std        30.137753    7.008418       1.488425
# min        13.000000    2.000000       1.000000
# 25%       132.000000   25.000000       2.000000
# 50%       149.000000   29.000000       3.000000
# 75%       157.000000   32.000000       4.000000
# max       224.000000   46.000000       9.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,6))#just to increase the figure size
sns.histplot(df[df['target']==0]['num_character'])
sns.histplot(df[df['target']==1]['num_character'],color='red')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target']==0]['num_words'])
sns.histplot(df[df['target']==1]['num_words'],color='red')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target']==0]['num_sentences'])
sns.histplot(df[df['target']==1]['num_sentences'],color='red')
plt.show()

# %%
sns.pairplot(df,hue='target')
plt.show()

# %%
df.head()
# Out:
#    target                                               text  num_character  \
# 0       0  Go until jurong point, crazy.. Available only ...            111
# 1       0                      Ok lar... Joking wif u oni...             29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...            155
# 3       0  U dun say so early hor... U c already then say...             49
# 4       0  Nah I don't think he goes to usf, he lives aro...             61
#
#    num_words  num_sentences
# 0         24              2
# 1          8              2
# 2         37              2
# 3         13              1
# 4         15              1

# %%
numeric_df = df.select_dtypes(include=['number'])
corr = numeric_df.corr()
plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True)
plt.show()

# %% [markdown]
# # 3.Text Preprocesing

# %% [markdown]
# ## lower case
# ## tokenization
# ## removing special characters
# ## stemming

# %%
import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\pc\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()
ps.stem('dancing')
ps.stem('loving')
# Out:
# 'love'

# %%
def transform_text(text):
    text=text.lower()
    text=nltk.word_tokenize(text)
    y=[]
    for i in text:
        if i.isalnum():
            y.append(i)
    text=y.copy()
    y.clear()
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)
    text=y[:]
    y.clear()

    for i in text:
        y.append(ps.stem(i))
        
    return " ".join(y)

# %%
transform_text('i loved the yt lectures on machine learning . how about you?')
# Out:
# 'love yt lectur machin learn'

# %%
transform_text('Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...')
# Out:
# 'go jurong point crazi avail bugi n great world la e buffet cine got amor wat'

# %%
transform_text("I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today.")
# Out:
# 'gon na home soon want talk stuff anymor tonight k cri enough today'

# %%
df['text'][10]
# Out:
# "I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today."

# %%
df['transformed_text']=df['text'].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_character  \
# 0       0  Go until jurong point, crazy.. Available only ...            111
# 1       0                      Ok lar... Joking wif u oni...             29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...            155
# 3       0  U dun say so early hor... U c already then say...             49
# 4       0  Nah I don't think he goes to usf, he lives aro...             61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from wordcloud) (2.3.3)
# Requirement already satisfied: pillow in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from wordcloud) (11.3.0)
# Requirement already satisfied: matplotlib in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from wordcloud) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from matplotlib->wordcloud) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from matplotlib->wordcloud) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %%
from wordcloud import WordCloud
wc=WordCloud(width=500,height=500,min_font_size=10,background_color='white')

# %%
spam_wc=wc.generate(df[df['target']==1]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(12,6))
plt.imshow(spam_wc)
plt.show()

# %%
ham_wc=wc.generate(df[df['target']==0]['transformed_text'].str.cat(sep=" "))
plt.imshow(ham_wc)
plt.show()

# %%
df.head()
# Out:
#    target                                               text  num_character  \
# 0       0  Go until jurong point, crazy.. Available only ...            111
# 1       0                      Ok lar... Joking wif u oni...             29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...            155
# 3       0  U dun say so early hor... U c already then say...             49
# 4       0  Nah I don't think he goes to usf, he lives aro...             61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
spam_corpus=[]
for msg in df[df['target']==1]['transformed_text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 9939

# %%
from collections import Counter

# %%
top_30 = pd.DataFrame(Counter(spam_corpus).most_common(30), columns=['Word', 'Count'])
# Plot
plt.figure(figsize=(12,6))
sns.barplot(x="Word", y="Count", data=top_30)
plt.xticks(rotation=90)
plt.show()

# %%
ham_corpus=[]
for msg in df[df['target']==0]['transformed_text'].tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 35404

# %%
top_30 = pd.DataFrame(Counter(ham_corpus).most_common(30), columns=['Word', 'Count'])
# Plot
plt.figure(figsize=(12,6))
sns.barplot(x="Word", y="Count", data=top_30)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # 4. Model Building

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv = CountVectorizer()
tfidf=TfidfVectorizer(max_features=3000)

# %%
X=tfidf.fit_transform(df['transformed_text']).toarray()

# %%
X.shape
# Out:
# (5169, 3000)

# %%
y=df['target'].values

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0], shape=(5169,))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb=GaussianNB()
mnb=MultinomialNB()
bnb=BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred1=gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.874274661508704
# [[790 106]
#  [ 24 114]]
# 0.5181818181818182

# %%
mnb.fit(X_train,y_train)
y_pred2=mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.9709864603481625
# [[896   0]
#  [ 30 108]]
# 1.0

# %%
bnb.fit(X_train,y_train)
y_pred3=bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.9835589941972921
# [[895   1]
#  [ 16 122]]
# 0.991869918699187

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

# %%
#  Naive Bayes model
nb = MultinomialNB()
nb_cv_score = cross_val_score(nb, X, y, cv=5, scoring='precision')

# %%
# Logistic Regression model
lr = LogisticRegression(max_iter=1000)
lr_cv_score = cross_val_score(lr, X, y, cv=5, scoring='precision')

# %%
# Compare average accuracies
print("Cross-Validation Accuracy Comparison:")
print(f"Naive Bayes Mean Precision:     {np.mean(nb_cv_score):.4f}")
print(f"Logistic Regression Mean Precision: {np.mean(lr_cv_score):.4f}")
# Out:
# Cross-Validation Accuracy Comparison:
# Naive Bayes Mean Precision:     0.9923
# Logistic Regression Mean Precision: 0.9727

# %%
# Optional: show all fold scores
print("\nNaive Bayes Scores:", nb_cv_score)
print("Logistic Regression Scores:", lr_cv_score)
# Out:
# Naive Bayes Scores: [1.         1.         1.         1.         0.96153846]
# Logistic Regression Scores: [0.96938776 1.         0.98863636 0.9375     0.96808511]

# %%
import pickle
pickle.dump(tfidf,open('vectorizer.pkl','wb'))
pickle.dump(mnb,open('model.pkl','wb'))

# %%
print(mnb.classes_)
# Out:
# [0 1]

# %%
import pickle

# vectorizer and upload model
tfidf = pickle.load(open('vectorizer.pkl', 'rb'))
mnb = pickle.load(open('model.pkl', 'rb'))

def predict_sms(text):
    vector = tfidf.transform([text])
    label = mnb.predict(vector)[0]
    return "This message is SPAM 🚨" if label == 1 else "This message is Not Spam ✅"

# taking input from users
user_sms = input("Enter an SMS: ")
print(predict_sms(user_sms))
# Out:
# Enter an SMS:  Hey, are we meeting tomorrow?
# This message is Not Spam ✅

# %%
import pickle

# vectorizer and upload model
tfidf = pickle.load(open('vectorizer.pkl', 'rb'))
mnb = pickle.load(open('model.pkl', 'rb'))

#  helper function
def predict_sms(text):
    # text ko vectorize karo
    vector = tfidf.transform([text])
    # model se prediction lo
    label = mnb.predict(vector)[0]
    return "SPAM" if label == 1 else "HAM"

# Example tests
print(predict_sms("Congratulations! You have won a lottery. Claim now!"))
print(predict_sms("Hey, are we meeting tomorrow?"))
# Out:
# SPAM
# HAM
